# %%
# Keyword mode, defaults to 'add' if we do keyword = value.
# Keywords can be invoked in any order
def some_func(param1, param2, mode="add"):
    if mode == "add":
        return param1 + param2
    elif mode == "sub": # Else-if
        return param1 - param2
    #return None
    # Functions implicitly return None at the end code execution gets there.
    # You can use 'else' in addition to the above to have a default fallback case.

# %%
print(some_func(10, 15, mode="add"))
# Out:
# 25

# %% [markdown]
# # Markdown
# ## Sub-heading
# Some normal text

# %%
import pandas as pd

# %%
df = pd.read_csv('./train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Magic commands, Jupyter has many of these.
# Matplotlib is the underlying framework for visualising. This tells it that we want graphics
# to be displayed inline after the cell, or notebook for after the cell with controls (pan, zoom, crop, etc).

#%matplotlib inline
# %matplotlib notebook

# %%
sns.distplot( df['Age'].fillna(0), bins=15  )
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.catplot('Pclass', data=df, kind="count")
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.catplot('Embarked', data=df, kind="count", hue="SibSp")
# Out:
# <img src="data:image/png;base64,..." width="838">
