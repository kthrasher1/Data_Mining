# %% [markdown]
# # Lab 1: Jupyter Notebook and PIP environment

# %% [markdown]
# ## Task 1

# %%
nine_am_lecture = True

if nine_am_lecture:
    print("Why!")
    tired = True
    
for i in range(10):
    print(i)

def my_function(param1, param2):
    return param1 + param2

print( my_function( 5, 8 ))
print( "My Number: " + str(my_function( 5, 8 )) )
print( tired )

# %% [markdown]
# ## Task 2

# %%
import pandas as pd

data = { 'Country': ['Belgium', 'India', 'Brazil'],
'Capital': ['Brussels', 'New Delhi', 'Brasilia'],
'Population': [11190846, 1303171035, 207847528]
}

df = pd.DataFrame(data, columns=['Country', 'Capital', 'Population'])

print(df)
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# ## Task 3

# %%
df = pd.read_csv('train.csv', names=['Passenger_ID', 'Survived', 'Class', 'Name', 'Sex', 'Age', 'Dependents', 'Parent_Child', 'Ticket', 'Fare', 'Cabin', 'Embarked'])

df = df.drop(df.index[0])

df
# Out:
#     Passenger_ID Survived Class  \
# 1              1        0     3
# 2              2        1     1
# 3              3        1     3
# 4              4        1     1
# 5              5        0     3
# ..           ...      ...   ...
# 887          887        0     2
# 888          888        1     1
# 889          889        0     3
# 890          890        1     1
# 891          891        0     3
#
#                                                   Name     Sex  Age  \
# 1                              Braund, Mr. Owen Harris    male   22
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                               Heikkinen, Miss. Laina  female   26
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                             Allen, Mr. William Henry    male   35
# ..                                                 ...     ...  ...
# 887                              Montvila, Rev. Juozas    male   27
# ...

# %%
df.describe()
# Out:
#        Passenger_ID Survived Class               Name   Sex  Age Dependents  \
# count           891      891   891                891   891  714        891
# unique          891        2     3                891     2   88          7
# top             776        0     3  Coleff, Mr. Satio  male   24          0
# freq              1      549   491                  1   577   30        608
#
#        Parent_Child Ticket  Fare        Cabin Embarked
# count           891    891   891          204      889
# unique            7    681   248          147        3
# top               0   1601  8.05  C23 C25 C27        S
# freq            678      7    43            4      644

# %% [markdown]
# #### `describe()` is used to view some basic statistical details such as mean, percentile ect...

# %%
df.head()
# Out:
#   Passenger_ID Survived Class  \
# 1            1        0     3
# 2            2        1     1
# 3            3        1     3
# 4            4        1     1
# 5            5        0     3
#
#                                                 Name     Sex Age Dependents  \
# 1                            Braund, Mr. Owen Harris    male  22          1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38          1
# 3                             Heikkinen, Miss. Laina  female  26          0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35          1
# 5                           Allen, Mr. William Henry    male  35          0
#
#   Parent_Child            Ticket     Fare Cabin Embarked
# 1            0         A/5 21171     7.25   NaN        S
# 2            0          PC 17599  71.2833   C85        C
# 3            0  STON/O2. 3101282    7.925   NaN        S
# 4            0            113803     53.1  C123        S
# ...

# %% [markdown]
# #### `Head()` first n rows for the object based on position

# %%
df.sample()
# Out:
#     Passenger_ID Survived Class                    Name   Sex Age Dependents  \
# 807          807        0     1  Andrews, Mr. Thomas Jr  male  39          0
#
#     Parent_Child  Ticket Fare Cabin Embarked
# 807            0  112050    0   A36        S

# %% [markdown]
# #### `Sample()` grabs a random entry
